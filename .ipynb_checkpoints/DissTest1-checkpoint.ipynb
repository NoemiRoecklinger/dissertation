# %%
import numpy as np
import pylab as plt
from sklearn.neighbors import KDTree
import scipy as scp

# %%
dataset = r"C:\Users\noemi\Noemi\UCL Master 2017 2018\Dissertation\Data\IQ Mulus\Cassette_idclass\Cassette_GT.txt"
Test = np.loadtxt(dataset, delimiter=",", skiprows= 2)
Test = Test[0:500]

# %%
Test = Test [0:500]

# %%
def covarianceMatrix(dataset, x,y):
    """
    Function to compute the covariance matrix.
    
    Input: Two data np.arrays representing a) all x-coordinates and b) all y-coordinates 
    Output: 2x2 covariance matrix (np.array)
    
    Alternatively, use the numpy command: np.cov(x,y)
    """
    
    n = x.size
    C = np.zeros(3)
    
    if n != y.size:
        print "X and Y must be of same dimensions."
    else:
        for i in range(C.shape[0]):
            for j in range(C.shape[1]):
                for pnt in dataset:
                    # For each point, access x and y in all combinations (xx, xy, yx, yy)
                    C[i][j] = C[i][j] + pnt[i]*pnt[j]
            
        C = (1/float(n)) * C
        
    return C

# %%
X = Test[:,0]
X.reshape(500,1)
Y = Test[:,1]
Y.reshape(500,1)
Z = Test[:,2]
Z.reshape(500,1)

print Z.shape
# Out:
# (500L,)

# %%
test1 = covarianceMatrix(Test, X, Y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-b16a1a6b90e3> in <module>()
# ----> 1 test1 = covarianceMatrix(Test, X, Y)
#
# <ipython-input-19-c885ff414333> in covarianceMatrix(dataset, x, y)
#      16     else:
#      17         for i in range(C.shape[0]):
# ---> 18             for j in range(C.shape[1]):
#      19                 for pnt in dataset:
#      20                     # For each point, access x and y in all combinations (xx, xy, yx, yy)
#
# IndexError: tuple index out of range

# %%
X.reshape(500,1)
# Out:
# array([[ 1903.38293457],
#        [ 1903.40454102],
#        [ 1903.42822266],
#        [ 1903.45153809],
#        [ 1903.47485352],
#        [ 1903.49450684],
#        [ 1903.51623535],
#        [ 1903.53833008],
#        [ 1903.56152344],
#        [ 1903.58215332],
#        [ 1903.60266113],
#        [ 1903.62646484],
#        [ 1903.64758301],
#        [ 1903.66772461],
#        [ 1903.68859863],
#        [ 1903.7064209 ],
#        [ 1903.72814941],
#        [ 1903.74755859],
#        [ 1903.76733398],
#        [ 1903.78796387],
#        [ 1903.80737305],
#        [ 1903.82714844],
#        [ 1903.84753418],
#        [ 1903.8684082 ],
#        [ 1903.88635254],
#        [ 1903.90454102],
#        [ 1903.9251709 ],
#        [ 1903.9420166 ],
#        [ 1903.95983887],
#        [ 1903.9798584 ],
#        [ 1903.99755859],
#        [ 1904.01489258],
#        [ 1904.03210449],
#        [ 1904.05053711],
#        [ 1904.06860352],
#        [ 1904.08300781],
#        [ 1904.10302734],
# ...

# %%
Y.shape
# Out:
# (5000L,)

# %%
np.concatenate((X,Y),axis=0)
# Out:
# array([  1903.38293457,   1903.40454102,   1903.42822266, ...,
#         21122.1953125 ,  21122.19140625,  21122.18945313])

# %%
print X[0], Y[0]
# Out:
# 1903.38293457 21122.4902344

# %%
Test[0]
# Out:
# array([  1.90338293e+03,   2.11224902e+04,   3.89911804e+01,
#          0.00000000e+00,   3.03040192e+08])

# %%
range(0,3)
# Out:
# [0, 1, 2]

# %%
Test[0:4,0:3]
# Out:
# array([[  1903.38293457,  21122.49023438,     38.99118042],
#        [  1903.40454102,  21122.48632813,     38.99028397],
#        [  1903.42822266,  21122.48046875,     38.99054718],
#        [  1903.45153809,  21122.4765625 ,     38.99121094]])

# %%
kdt = KDTree(Test, leaf_size=30, metric='euclidean')

# %%
vector = kdt.query(Test, k=5, return_distance=False)

# %%
vector.shape
# Out:
# (500L, 5L)

# %%
vector[2]
# Out:
# array([2, 3, 1, 0, 4], dtype=int64)

# %%
for elem in vector[2]:
    print Test[elem]
# Out:
# [  1.90342822e+03   2.11224805e+04   3.89905472e+01   0.00000000e+00
#    3.03040192e+08]
# [  1.90345154e+03   2.11224766e+04   3.89912109e+01   0.00000000e+00
#    3.03040192e+08]
# [  1.90340454e+03   2.11224863e+04   3.89902840e+01   0.00000000e+00
#    3.03040192e+08]
# [  1.90338293e+03   2.11224902e+04   3.89911804e+01   0.00000000e+00
#    3.03040192e+08]
# [  1.90347485e+03   2.11224707e+04   3.89914665e+01   0.00000000e+00
#    3.03040192e+08]

# %%
for i, point in enumerate(Test):
    for elem in vector[i]:
        print "ok"
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...

# %%
X = Test[:,0]
Y = Test[:,1]
Z = Test[:,2]
C = np.cov(X,Y)

# %%
C.shape
# Out:
# (2L, 2L)

# %%
for i in range(0, 7):
    print i
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
np.zeros(5)
# Out:
# array([ 0.,  0.,  0.,  0.,  0.])
