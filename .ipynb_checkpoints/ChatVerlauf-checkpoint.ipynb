# %%
# This is just for me and the cat history (backup)

# %%
import pandas as pd

# %%
# Define a data frame 
CHAT_PATH = 'C:\\Users\\noemi\\Noemi\\WhatsApp Chats'
FILE_NAME = '\\Dave.csv'
df = pd.read_csv(CHAT_PATH + FILE_NAME, delimiter=";")
df
# Out:
#            Date.1  User.2                                               Chat
# 0      13.05.2017   Noemi                                             Coming
# 1      13.05.2017   Noemi                                   At the beach atm
# 2      17.05.2017   Noemi          It's fine, apparently I'm a whiney pussy.
# 3      17.05.2017    Dave                                    That's not true
# 4      17.05.2017   Noemi   It's the ribs and she couldn't explain why it...
# 5      17.05.2017    Dave                Well that's not really satisfactory
# 6      17.05.2017   Noemi                                           It's not
# 7      17.05.2017    Dave            Would you like me to ring my dad later?
# 8      17.05.2017   Noemi                              That's so nice of you
# 9      17.05.2017   Noemi               I'll rather wait for three more days
# 10     17.05.2017   Noemi                 She told me not to do any exercise
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14038 entries, 0 to 14037
# Data columns (total 3 columns):
# Date.1    13939 non-null object
# User.2    13939 non-null object
# Chat      13937 non-null object
# dtypes: object(3)
# memory usage: 329.1+ KB
