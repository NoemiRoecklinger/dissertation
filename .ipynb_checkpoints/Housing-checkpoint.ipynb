# %%
# This is for Operating system, e.g. get working directory etc 
import os
# Read and write .tar files (compressed files)
import tarfile
# This is to provide compartibility between Python 2.7 and Python 3, probably not needed here anyways
from six.moves import urllib
# Pandas: statistics like excel
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# This is for splitting the training and testing data sets
from sklearn.model_selection import train_test_split
# This is for shuffling the data and get stratified data
from  sklearn.model_selection import StratifiedShuffleSplit
# This is to show the data on a map
import matplotlib.image as mpimg
# For scatter plots and covariance 
from pandas.plotting import scatter_matrix
# This is to replace NA values in the data set provided we only have numerical values 
from sklearn.preprocessing import Imputer
# This is to convert categorial data into numerical data
from sklearn.preprocessing import LabelEncoder
# This is for one-hot encoding
from sklearn.preprocessing import OneHotEncoder
# This is for doing numerical coding and one-hot coding at once 
from sklearn.preprocessing import LabelBinarizer
# Transformation pipeline
from sklearn.pipeline import Pipeline
# For standard scaling 
from sklearn.preprocessing import StandardScaler
# To also include categorial data in the pipeline 
from sklearn.pipeline import FeatureUnion
# For linear regression model
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline

# %% [markdown]
# # Read the files in and fetch data

# %%
DOWNLOAD_ROOT = r"https://github.com/ageron/handson-ml/"
HOUSING_PATH = r"datasets/housing"
HOUSING_URL = DOWNLOAD_ROOT + HOUSING_PATH + r"/housing.tgz"

# %%
# Download the data from GitHub 
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
# We only need to do that once
fetch_housing_data()
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# <ipython-input-123-05738cbc196a> in <module>()
#       1 # We only need to do that once
# ----> 2 fetch_housing_data()
#
# <ipython-input-122-f7e5b5c527d3> in fetch_housing_data(housing_url, housing_path)
#       5     tgz_path = os.path.join(housing_path, "housing.tgz")
#       6     urllib.request.urlretrieve(housing_url, tgz_path)
# ----> 7     housing_tgz = tarfile.open(tgz_path)
#       8     housing_tgz.extractall(path=housing_path)
#       9     housing_tgz.close()
#
# C:\Users\noemi\AppData\Local\Continuum\anaconda2\lib\tarfile.pyc in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1678                         fileobj.seek(saved_pos)
#    1679                     continue
# -> 1680             raise ReadError("file could not be opened successfully")
#    1681
#    1682         elif ":" in mode:
#
# ...

# %%
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    # we can give it the path in here also directly 
    return pd.read_csv(csv_path)

# %%
# read the csv file in 
housing = load_housing_data()
# show the info about the file 
housing.info()
# shows the first 5 lines 
housing.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# ...

# %% [markdown]
# # Get info about the data sets

# %%
# For when we want to see how many different values there are
# makes more sense for categorial data 
# Without value_counts() we see all instances
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
# For each data column, we get statistical values that describe the data column 
# e.g. how many instances, what is the mean / max / min value etc 
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# To get the specific values, we can just type: 
housing['total_rooms'].mean()
# Out:
# 2635.7630813953488

# %%
# E.g. for each data column, get and save the mean value
lut_datacolumns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms']
store = []
for elem in lut_datacolumns:
    print housing[elem].mean()
    store.append(housing[elem].mean())
print store
# Out:
# -119.569704457
# 35.6318614341
# 28.6394864341
# 2635.7630814
# [-119.56970445736148, 35.6318614341087, 28.639486434108527, 2635.7630813953488]

# %%
# Histogram 
# Automatically plots respective data column and how often each value occurs 
housing.hist(bins=50, figsize=(20,15))
# plt.savefig('foo.png')
plt.show()
# We see: whenever there is a big peak to the right (high value), there was a cap in the data, so everything higher than
# than this value is probably in this bin, this doesnt allow the desired normal distribution (NDIST)

# %% [markdown]
# # Create a test set
# Whenever we do ML, we need to have a test set, which is smaller than the training set
# we train the algorithm on the training set and then test it on test set
#
# There are different ways to do so, but we use a) the one proposed by scikit learn
# and b) the one stratified version (Book: 52, I dont quite understand it so far, this makes sure that test data is representative for whole data set)

# %%
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
# train_set.info(), test_set.info()

# %%
# This is to plot only one value
train_set['median_income'].hist(bins=50), plt.show()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1f5c4cf8>, None)

# %%
# Here, we plot the distribution of the training and test data set 
plt.figure(figsize=(9,9))
plt.subplot(231), train_set['median_income'].hist(bins=10), plt.title('Whole data')
plt.subplot(232), train_set['median_income'].hist(bins=10), plt.title('Training data')
plt.subplot(233), test_set['median_income'].hist(bins=10), plt.title('Test data')
plt.show()

# %%
# From here on stratified 

# Divide by 1.5 to limit the number of income categories 
# Can just create a new column like that 
housing["income_cat"] = np.ceil(housing["median_income"] / 1.5)
# Label those above 5 as 5
# inplace = True is like in C++ where we overwrite an object rather than creating a copy of it
# so we dont return anything, but we overwrite the object we operate on 
# Where smaller than five, do nothing; where this is not true replace with 5.0
housing["income_cat"].where(housing["income_cat"] < 5, 5.0, inplace=True)

# %%
housing['income_cat'].hist()

# %%
# Sorted by amount of values 
housing["income_cat"].value_counts()
# Out:
# 3.0    7236
# 2.0    6581
# 4.0    3639
# 5.0    2362
# 1.0     822
# Name: income_cat, dtype: int64

# %%
# This splits the data w.r.t. the median income category 
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]
    
# We use that when one category is particulaly important to us and we need to make sure that it has enough instances that
# represent the whole data set

# %%
# Values for full data set  
housing['income_cat'].value_counts() / len(housing)
# Values for test data set created by stratified sampling
strat_test_set['income_cat'].value_counts() / len(strat_test_set)
# Values for test data set random
# Out:
# 3.0    0.350533
# 2.0    0.318798
# 4.0    0.176357
# 5.0    0.114583
# 1.0    0.039729
# Name: income_cat, dtype: float64

# %%
# Create a table for our data 
def income_cat_proportions(data):
    return data["income_cat"].value_counts() / len(data)

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# Look at Panas Explanation file I wrote to understand that better 
compare_props = pd.DataFrame({
    "Overall": income_cat_proportions(housing),
    "Stratified": income_cat_proportions(strat_test_set),
    "Random": income_cat_proportions(test_set),
}).sort_index()
compare_props["Rand. %error"] = 100 * compare_props["Random"] / compare_props["Overall"] - 100
compare_props["Strat. %error"] = 100 * compare_props["Stratified"] / compare_props["Overall"] - 100

# %%
compare_props
# Out:
#       Overall    Random  Stratified  Rand. %error  Strat. %error
# 1.0  0.039826  0.040213    0.039729      0.973236      -0.243309
# 2.0  0.318847  0.324370    0.318798      1.732260      -0.015195
# 3.0  0.350581  0.358527    0.350533      2.266446      -0.013820
# 4.0  0.176308  0.167393    0.176357     -5.056334       0.027480
# 5.0  0.114438  0.109496    0.114583     -4.318374       0.127011

# %%
# Now we really dont need the category column after testing the test data set, so we can drop the column for both the 
# stratified training and test data set 

for col in (strat_test_set, strat_train_set):
    col.drop(['income_cat'], axis=1, inplace=True)

# %% [markdown]
# # Discover and visualise the data
#
# Page 53
#
# Important to only use the training data set now and dont touch the test data again

# %%
# Copy the training data set so we can not harm it 
# We overwrite housing now and have a smaller training data set 
housing = strat_train_set.copy()

# %%
# This is alternative way to plot the data instead of plt.blubb
# Alpha sets the transparency (between 0 (transparent) and 1 (opaque))
housing.plot(kind='scatter', x = 'longitude', y = 'latitude', c='r', alpha=0.1)

# %%
# Now we can change the size (s) of the points depending on values and also the colour (c) depending on another value 

housing.plot(kind='scatter', x = 'longitude', y = 'latitude', alpha = 0.4, s=housing['population']/100, label='population',
             c='median_house_value', cmap = plt.get_cmap('jet'), colorbar=True)

# %%
# Imread the image file 
california_img = mpimg.imread('images/california.png')
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                       s=housing['population']/100, label="Population",
                       c="median_house_value", cmap=plt.get_cmap("jet"),
                       colorbar=False, alpha=0.4,
                      )
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
          cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar()
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
plt.savefig("california_housing_prices_plot")
plt.show()

# %% [markdown]
# # Looking for correlations
#
# We can find the correlations between all attributes as the dataset is not too big
#
# Also called: Standard correlation coefficient (Pearson's r)
#
# Negative value: negative correlation, if one increases, the other decreases
#
# Positive: positive correlation, if one increases, the other increases
#
# Around 0: no correlation

# %%
# Finds the correlation between all these values
corr_matrix = housing.corr()
#print corr_matrix

# %%
# Now we can look at how much certain values correlate with the median house value
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047689
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# Name: median_house_value, dtype: float64

# %%
# We can also get information about the data and correlation by plotting the scatter diagrams
# However, as we have 11 classes, there would be 11^2 plots, i.e. 121, so here we focus on a few 

attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
# I want to suppress the output (text after plot, all these lines), so I use a semicolon and plt.show()
scatter_matrix(housing[attributes], figsize=(12,8), alpha = 0.2);
plt.show()

# %% [markdown]
# ### Explanation for the scatter plot
#
# In diagonal, the value would be exactly 1; i.e. full of straight lines, would not be useful.
# Therefore, a histogram of the value itself is plotted
# As we saw before, the median_house_value (this is what we want in the end = label) is mostly correlated to the median_income. Therefore we look at the plot closer

# %%
# Look at median_income and median_house_value
housing.plot(kind='scatter', x='median_income', y ='median_house_value', alpha=0.1);

# %% [markdown]
# What we see here, is that the correlation is quite strong. We have a clear trend in the data set
# Upwards trend, points not too dispersed
# Note the line on top. This is due to the price cap that was set on all the collected data. But we also see more straight horizontal lines, one at 450, one at 350 and maybe even one at 280. Maybe it would be good to remove the lines from the data set, otherwise the algorithm learns these things

# %% [markdown]
# ### Attribute combinations
# Whenever we look at data, it might be more meaningful to combine them. So instead of taking one value and just trust it like
# that, we can combine it with another one. This way, we can possibly improve our ML model
# e.g. the population per household could be very interesting; also the total number of bedrooms does not mean much on its own, but it would be more meaningful to combine it with households

# %%
# Create new columns with new attributes 
housing['rooms_per_household'] = housing['total_rooms'] / housing['households']
housing['bedrooms_per_room'] = housing['total_bedrooms'] / housing['total_rooms']
housing['population_per_household'] = housing['population'] / housing['households']

# %%
# Now we look at the new correlation matrix in comparsion to the old one 
new_corr_matrix = housing.corr()
print new_corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.687160
# rooms_per_household         0.146285
# total_rooms                 0.135097
# housing_median_age          0.114110
# households                  0.064506
# total_bedrooms              0.047689
# population_per_household   -0.021985
# population                 -0.026920
# longitude                  -0.047432
# latitude                   -0.142724
# bedrooms_per_room          -0.259984
# Name: median_house_value, dtype: float64

# %%
# We see that the correlations have changed and we see new important correlations 
print corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047689
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# Name: median_house_value, dtype: float64

# %% [markdown]
# # Prepare the data for ML algorithms
# So far, we have analysed the data only and created a training and a test set, but now we actually want to prepare the data.
# For whatever reason, we do not use the values we just created (why though?) and we go back to the initial training and test data set. It was called strat_train_set and then we seperate it in label and not label.

# %%
housing = strat_train_set.drop('median_house_value', axis=1)
housing_labels = strat_train_set['median_house_value'].copy()

# %% [markdown]
# ### Data cleaning
# First we need to get rid of NA (here, we only have no values in one column, but for future datasets we cannot be so sure about that). we have 3 options
#
# a) Whenever we find a NA in the specified column (where we know we have missing data) we just delete the whole row
#
# b) We can drop the whole column and just dont use it at all (we would loose a lot of information here)
#
# c) Replace the NA with a suitable value (e.g. the median of the whole column). It is curucial to store that value though as we will need exactly the same value for the test data set later on to replace NA.

# %%
# Show the first few lines where data is missing
sample_incomplete_rows = housing[housing.isnull().any(axis=1)].head()
sample_incomplete_rows
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4629     -118.30     34.07                18.0       3759.0             NaN
# 6068     -117.86     34.01                16.0       4632.0             NaN
# 17923    -121.97     37.35                30.0       1955.0             NaN
# 13656    -117.30     34.05                 6.0       2155.0             NaN
# 19252    -122.79     38.48                 7.0       6837.0             NaN
#
#        population  households  median_income ocean_proximity
# 4629       3296.0      1462.0         2.2708       <1H OCEAN
# 6068       3038.0       727.0         5.1762       <1H OCEAN
# 17923       999.0       386.0         4.6328       <1H OCEAN
# 13656      1039.0       391.0         1.6675          INLAND
# 19252      3468.0      1405.0         3.1662       <1H OCEAN

# %%
# all 3 options a -c 
#housing.dropna(subset=['total_bedrooms'])
#housing.drop('total_bedrooms', axis = 1)
#median = housing['total_bedrooms'].median()
#housing['total_bedrooms'].fillna(median)

# %% [markdown]
# Instead of using these options, sklearn has a class that deals with this issue. For all columns, it looks for NA and
# then replaces the values by e.g. the median

# %%
# Create an instance of the class Imputer
imputer = Imputer(strategy='median')
# Get rid of any non-numerical values (categorial)
housing_num = housing.drop(['ocean_proximity'], axis=1)
# Fit the imputer (i.e. just calculating the median values for each column)
imputer.fit(housing_num)
imputer.statistics_ # this is exactly the same as housing_num.median()
# Out:
# array([ -118.51  ,    34.26  ,    29.    ,  2119.5   ,   433.    ,
#         1164.    ,   408.    ,     3.5409])

# %%
# This gives us the whole dataset but all the NA values were replaced by median
# Careful: the result is a np.array and not a data frame anymore (pandas)
X = imputer.transform(housing_num)

# %%
# Put it back into Pandas dataframe 
housing_tr = pd.DataFrame(X, columns=housing_num.columns)
housing_tr.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -121.89     37.29                38.0       1568.0           351.0
# 1    -121.93     37.05                14.0        679.0           108.0
# 2    -117.20     32.77                31.0       1952.0           471.0
# 3    -119.61     36.31                25.0       1847.0           371.0
# 4    -118.59     34.23                17.0       6592.0          1525.0
#
#    population  households  median_income
# 0       710.0       339.0         2.7042
# 1       306.0       113.0         6.4214
# 2       936.0       462.0         2.8621
# 3      1460.0       353.0         1.8839
# 4      4459.0      1463.0         3.0347

# %% [markdown]
# # Handling text data and categorial data
# We cannot work with text data, so we can just convert it into numbers
# However, we must be careful because the numbers and their order do not represent anything really

# %%
# Create an instance of the class LabelEncoder
encoder = LabelEncoder()
# Take the column that contains categorial data
housing_cat = housing['ocean_proximity']
# Take all the values and encode them into numerical values
housing_cat_encoded = encoder.fit_transform(housing_cat)
# will return values from 0 to ...
housing_cat_encoded
# Out:
# array([0, 0, 4, ..., 1, 0, 3], dtype=int64)

# %%
# Whenever we want to get sth that has been learnt, we write an underscore 
# here, we print the classes we have now, i.e. inland = 1, island = 2 etc 
print encoder.classes_
# Out:
# ['<1H OCEAN' 'INLAND' 'ISLAND' 'NEAR BAY' 'NEAR OCEAN']

# %%
# However, the classes are not sorted, 0 and 1 are not more similar than 0 and 4, so this will be a problem for
# the algorithm therefore we will have to do one-hot encoding (1 if true, 0 if not)

encoder = OneHotEncoder()
housing_cat_1hot = encoder.fit_transform(housing_cat_encoded.reshape(-1,1))
# Output is a sparse matrix instead of numpy array 
housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %%
# What we did so far, is converting the categorial data into numerical data and then performed one-hot encoding. However, we 
# can do these 2 steps also at once by using another sklearn class: label binarizer
# This returns a dense matrix though, so will take up a lot of memory
# Therefore, we add: 
encoder = LabelBinarizer(sparse_output = True)
housing_cat_1hot = encoder.fit_transform(housing_cat)
housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<type 'numpy.int32'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Custom transformations
# I dont really understand that, so just copy it

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# column index
rooms_ix, bedrooms_ix, population_ix, household_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True): # no *args or **kargs
        self.add_bedrooms_per_room = add_bedrooms_per_room
    def fit(self, X, y=None):
        return self  # nothing else to do
    def transform(self, X, y=None):
        rooms_per_household = X[:, rooms_ix] / X[:, household_ix]
        population_per_household = X[:, population_ix] / X[:, household_ix]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household,
                         bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)
housing_extra_attribs = attr_adder.transform(housing.values)

# %%
housing_extra_attribs = pd.DataFrame(
    housing_extra_attribs,
    columns=list(housing.columns)+["rooms_per_household", "population_per_household"])
housing_extra_attribs.head()
# Out:
#   longitude latitude housing_median_age total_rooms total_bedrooms population  \
# 0   -121.89    37.29                 38        1568            351        710
# 1   -121.93    37.05                 14         679            108        306
# 2    -117.2    32.77                 31        1952            471        936
# 3   -119.61    36.31                 25        1847            371       1460
# 4   -118.59    34.23                 17        6592           1525       4459
#
#   households median_income ocean_proximity rooms_per_household  \
# 0        339        2.7042       <1H OCEAN             4.62537
# 1        113        6.4214       <1H OCEAN             6.00885
# 2        462        2.8621      NEAR OCEAN             4.22511
# 3        353        1.8839          INLAND             5.23229
# 4       1463        3.0347       <1H OCEAN             4.50581
#
#   population_per_household
# 0                   2.0944
# 1                  2.70796
# 2                  2.02597
# ...

# %%
num_pipeline = Pipeline([
        ('imputer', Imputer(strategy="median")),
        ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
housing_num_tr
# Out:
# array([[-1.15604281,  0.77194962,  0.74333089, ..., -0.31205452,
#         -0.08649871,  0.15531753],
#        [-1.17602483,  0.6596948 , -1.1653172 , ...,  0.21768338,
#         -0.03353391, -0.83628902],
#        [ 1.18684903, -1.34218285,  0.18664186, ..., -0.46531516,
#         -0.09240499,  0.4222004 ],
#        ...,
#        [ 1.58648943, -0.72478134, -1.56295222, ...,  0.3469342 ,
#         -0.03055414, -0.52177644],
#        [ 0.78221312, -0.85106801,  0.18664186, ...,  0.02499488,
#          0.06150916, -0.30340741],
#        [-1.43579109,  0.99645926,  1.85670895, ..., -0.22852947,
#         -0.09586294,  0.10180567]])

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# Create a class to select numerical or categorical columns 
# since Scikit-Learn doesn't handle DataFrames yet
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %% [markdown]
# ### Problem with using LabelBinarizer in pipeline:
#
# There is a problem with the code in the book. It does not work when calling LabelBinarizer in the pipeline - function.
# However, this is not the perfect solution. While it works, the data will be different now than in the book. But I will not work with categorial data anyways, so this does not really affect me.
#
# Solve with this code: https://github.com/scikit-learn/scikit-learn/issues/3112

# %%
# THIS IS ONLY FOR THE PIPELINE
class CustomBinarizer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None,**fit_params):
        return self
    def transform(self, X):
        return LabelBinarizer().fit(X).transform(X)

# %%
class LabelBinarizerPipelineFriendly(LabelBinarizer):
    def fit(self, X, y=None):
        """this would allow us to fit the model based on the X input."""
        super(LabelBinarizerPipelineFriendly, self).fit(X)
    def transform(self, X, y=None):
        return super(LabelBinarizerPipelineFriendly, self).transform(X)

    def fit_transform(self, X, y=None):
        return super(LabelBinarizerPipelineFriendly, self).fit(X).transform(X)

# %%
num_attribs = list(housing_num)
cat_attribs = ["ocean_proximity"]

num_pipeline = Pipeline([
        ('selector', DataFrameSelector(num_attribs)),
        ('imputer', Imputer(strategy="median")),
        ('attribs_adder', CombinedAttributesAdder()),
        ('std_scaler', StandardScaler()),
    ])

cat_pipeline = Pipeline([
    ('selector', DataFrameSelector(cat_attribs)),
    ('label_binarizer', LabelBinarizerPipelineFriendly())
])

# %%
full_pipeline = FeatureUnion(transformer_list=[
        ("num_pipeline", num_pipeline),
        ("cat_pipeline", cat_pipeline),
    ])

# %%
housing_prepared = full_pipeline.fit_transform(housing)
# Now I have a different shape than proposed in book for whatever reason 
housing_prepared.shape
# Out:
# (16512L, 16L)

# %% [markdown]
# # Select and train a model
#
# Finally ML!

# %% [markdown]
# ### Regression
# First, we take the training data and train a linear regression model

# %%
# Create an instance
lin_reg = LinearRegression()
# This fits the model to the data. This is working now, this is done. 
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Now we can test it from the training data set (not testing, we evaluate it first on the training data)
# This gives us the first 5 values in the label dataset 
housing_labels.iloc[:5]
# Out:
# 17606    286600.0
# 18632    340600.0
# 14650    196900.0
# 3230      46300.0
# 3555     254500.0
# Name: median_house_value, dtype: float64

# %%
# let's try the full pipeline on a few training instances# let's  
some_data = housing.iloc[:5]
some_labels = housing_labels.iloc[:5]
some_data_prepared = full_pipeline.fit_transform(some_data)

# print("Predictions:", lin_reg.predict(some_data_prepared))
# OKAY THIS DOES NOT WORK

# %% [markdown]
# # OKAY it doesnt work - now: my version

# %%
housing.info()
housing_labels.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16512 entries, 17606 to 15775
# Data columns (total 9 columns):
# longitude             16512 non-null float64
# latitude              16512 non-null float64
# housing_median_age    16512 non-null float64
# total_rooms           16512 non-null float64
# total_bedrooms        16354 non-null float64
# population            16512 non-null float64
# households            16512 non-null float64
# median_income         16512 non-null float64
# ocean_proximity       16512 non-null object
# dtypes: float64(8), object(1)
# memory usage: 1.3+ MB

# %%
# Create numerical data only 
housing_numNoemi = housing.drop(['ocean_proximity'], axis = 1)
# Get rid of NAN values
imputer = Imputer(strategy='median')
X = imputer.fit_transform(housing_numNoemi)
housing_transfNoemi = pd.DataFrame(X, columns = housing_numNoemi.columns)
# This works now, but it will be bad because the data has not been standardised 
# Standardise it
#std_scaler = StandardScaler()
#housing_scaledNoemi = std_scaler.fit_transform(housing_transfNoemi)

# %%
lin_reg = LinearRegression()
lin_reg.fit(housing_transfNoemi, housing_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# let's try the full pipeline on a few training instances# let's  
some_data = housing_transfNoemi.iloc[:5]
some_labels = housing_labels.iloc[:5]

print("Predictions:", lin_reg.predict(some_data))
# Out:
# ('Predictions:', array([ 207533.05517344,  322908.0066498 ,  205636.93169928,
#          75429.96006052,  188528.17569526]))

# %%
print("Labels:", list(some_labels))
# Out:
# ('Labels:', [286600.0, 340600.0, 196900.0, 46300.0, 254500.0])

# %%
from sklearn.metrics import mean_squared_error
housing_predictions = lin_reg.predict(housing_transfNoemi)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
print lin_rmse
# Out:
# 69958.3994033

# %%
from  sklearn.metrics import mean_absolute_error
lin_mae = mean_absolute_error(housing_labels, housing_predictions)
print lin_mae
# Out:
# 50973.0473934

# %% [markdown]
# ### This works really bad, so try decision trees

# %%
# Now that is a bad result, try a decision tree instead of a linear regression model 

from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_transfNoemi, housing_labels)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
# Now
